# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df=pd.read_csv('sms_spam.csv')
df
# Out:
#       type                                               text
# 0      ham  Hope you are having a good week. Just checking in
# 1      ham                            K..give back my thanks.
# 2      ham        Am also doing in cbe only. But have to pay.
# 3     spam  complimentary 4 STAR Ibiza Holiday or £10,000 ...
# 4     spam  okmail: Dear Dave this is your final notice to...
# ...    ...                                                ...
# 5554   ham  You are a great role model. You are giving so ...
# 5555   ham  Awesome, I remember the last time we got someb...
# 5556  spam  If you don't, your prize will go to another cu...
# 5557  spam  SMS. ac JSco: Energy is high, but u may not kn...
# 5558   ham                    Shall call now dear having food
#
# [5559 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# type    0
# text    0
# dtype: int64

# %%
df.describe()
# Out:
#         type                    text
# count   5559                    5559
# unique     2                    5156
# top      ham  Sorry, I'll call later
# freq    4812                      30

# %%
df.groupby('type').describe()
# Out:
#       text
#      count unique                                                top freq
# type
# ham   4812   4503                             Sorry, I'll call later   30
# spam   747    653  Please call our customer service representativ...    4

# %%
text=df.iloc[:,-1]
text
# Out:
# 0       Hope you are having a good week. Just checking in
# 1                                 K..give back my thanks.
# 2             Am also doing in cbe only. But have to pay.
# 3       complimentary 4 STAR Ibiza Holiday or £10,000 ...
# 4       okmail: Dear Dave this is your final notice to...
#                               ...
# 5554    You are a great role model. You are giving so ...
# 5555    Awesome, I remember the last time we got someb...
# 5556    If you don't, your prize will go to another cu...
# 5557    SMS. ac JSco: Energy is high, but u may not kn...
# 5558                      Shall call now dear having food
# Name: text, Length: 5559, dtype: object

# %%
corpus=[]
for i in range(0,5559):
  text=re.sub('[^a-zA-Z]',' ',df['text'][i])
  text=text.lower()
  text=text.split()
  ps=PorterStemmer()
  all_stopwords=stopwords.words('english')
  text=[ps.stem(word) for word in text if not word in set(all_stopwords)]
  text=' '.join(text)
  corpus.append(text)

print(corpus)
# Out:
# ['hope good week check', 'k give back thank', 'also cbe pay', 'complimentari star ibiza holiday cash need urgent collect landlin lose box sk wp ppm', 'okmail dear dave final notic collect tenerif holiday cash award call landlin tc sae box cw wx ppm', 'aiya discuss later lar pick u', 'much buzi', 'pleas ask mummi call father', 'marvel mobil play offici ultim spider man game ur mobil right text spider game send u free ball wallpap', 'fyi usf swing room whenev', 'sure thing big man hockey elect go longer hour though', 'anyth lor', 'march end readi call sure problem capit never complet far work ladi', 'hmm well night night', 'k sure get noon see', 'ha ha cool cool chikku chikku db', 'darren say dat u meet da ge den dun meet dinner co later u leav xy feel awkward den u meet lunch lor', 'dint tell anyth angri told abi', 'u u wan come come lor din c stripe skirt', 'u win music gift voucher everi week start txt word draw tsc www ldew com skillgam winaweek age ppermesssubscript', 'mro come gym machan goodnight', 'arr birthday today wish get oscar', 'read gud habit nan bari hudgi yorg pataistha ertini kano', 'sent score sopha secondari applic school think think appli research cost also contact joke ogunrind school one less expens one', 'could read love answer', 'bank say money', 'well desper call armand', 'fuuuuck need stop sleepin sup', 'weather', 'ok thanx', 'ok ok ok what ur today plan', 'appl day doctor tulsi leaf day cancer lemon day fat cup milk day bone problm litr watr day diseas snd th u care', 'sorri call later', 'exhaust train morn much wine pie sleep well', 'u nokia plu free digit camera u get u win free auction take part send nokia pobox tcr w', 'ron say fri leh n said ding tai feng cant make reserv said wait lor', 'call carlo phone vibrat act might hear text', 'oh k got job what', 'spjanuari male sale hot gay chat cheaper call nation rate p min cheap p min peak stop text call p min', 'yeah think use gt atm regist sure anyway help let know sure readi', 'nationwid auto centr someth like newport road like', 'call meet', 'yeah sure leav min', 'urgent mobil number award prize guarante call land line claim valid hr ppm', 'mah b pick tomorrow', 'dun believ wat', 'sent u part', 'hey what plan sat', 'come sec somebodi want see', 'yup izzit still rain heavili co e mrt c outsid', 'think go finn come', 'prasanth ettan mother pass away last night pray famili', 'enjoy shower possess pour u ur love one bcoz world lie golden gift love truli', 'realli skateboard despit fact get thrown wind bandag arm everi five minut', 'pleas give us connect today decim refund bill', 'congratul ur award cd voucher gift guarante free entri wkli draw txt music tnc www ldew com win ppmx age', 'mum go robinson alreadi', 'got meh', 'fine thank', 'awesom deal gate charl told last night uh yeah', 'thought get watch co that kind thing u get th love much', 'safe trip nigeria wish happi soon compani share moment', 'hey u fanci meetin cha hav lil beverag txt ring meet l r quit tire got v pist love pete x x x', 'mean post wrote like mani time ritten stuff let sit feel time angri left hit send stop check phone got car said sleep bore time clean fold laundri etc least make bed', 'want mapquest someth look usf dogwood drive tini street park lot', 'ha ha nan yalrigu heltini iyo kothi chikku u share mani thing wit far told bodi even utter word abt u ur trust much tell other plz nxt time dont use word ok chikku b', 'becoz jan whn al post ofic holiday cn go fr post ofic got duffer', 'good think could send pix would love see top bottom', 'beauti truth graviti read care heart feel light someon feel heavi someon leav good night', 'buzz hey love think hope day goe well sleep miss babe long moment togeth love smile', 'lara said loan', 'dunno leh cant rememb mayb lor wat time r meet tmr', 'wat ur opinion abt abt charact', 'oh oh wast den muz chiong sat n sun liao', 'work right', 'bring home wendi', 'ok go sleep hope meet', 'allo brave buse taken train triumph mean b ham jolli good ...

# %%
cv=CountVectorizer()
X=cv.fit_transform(corpus).toarray()
y=df.iloc[:,0]
y
# Out:
# 0        ham
# 1        ham
# 2        ham
# 3       spam
# 4       spam
#         ...
# 5554     ham
# 5555     ham
# 5556    spam
# 5557    spam
# 5558     ham
# Name: type, Length: 5559, dtype: object

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# ##Naive Bayes

# %%
mb=MultinomialNB()
mb.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=mb.predict(X_test)
y_pred
# Out:
# array(['ham', 'ham', 'ham', ..., 'ham', 'ham', 'ham'], dtype='<U4')

# %%
accuracies=cross_val_score(estimator=mb,X=X_train,y=y_train,cv=10) # cv isthe number of folds we eant in our training set
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
# print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))

# %%
cm=confusion_matrix(y_test,y_test)
print(cm)
accuracy_score(y_pred,y_test)
# Out:
# [[979   0]
#  [  0 133]]
# 0.9802158273381295

# %% [markdown]
# ##Decision Tree

# %%
dt=DecisionTreeClassifier(criterion='entropy',random_state=0)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred=dt.predict(X_test)
y_pred
cm=confusion_matrix(y_test,y_test)
print(cm)
accuracy_score(y_pred,y_test)
# Out:
# [[979   0]
#  [  0 133]]
# 0.9703237410071942

# %%
accuracies=cross_val_score(estimator=dt,X=X_train,y=y_train,cv=10) # cv isthe number of folds we eant in our training set
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
# Out:
# Accuracy: 96.87 %
# Standard Deviation: 0.97 %

# %% [markdown]
# ##Random Forest Classifier

# %%
rd=RandomForestClassifier(n_estimators=10,random_state=0)
rd.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=0)

# %%
accuracies=cross_val_score(estimator=rd,X=X_train,y=y_train,cv=25) # cv isthe number of folds we eant in our training set
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
# print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy: 97.03 %

# %%
y_pred=rd.predict(X_test)
y_pred
cm=confusion_matrix(y_test,y_test)
print(cm)
accuracy_score(y_pred,y_test)
# Out:
# [[979   0]
#  [  0 133]]
# 0.9757194244604317
